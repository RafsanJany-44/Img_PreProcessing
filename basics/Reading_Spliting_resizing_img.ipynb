# %%
import cv2
from matplotlib import pyplot as plt

# %%
image_path="basic_guess.jpg"

img = cv2.imread(image_path)

# %%
img.shape
# Out:
# (1080, 1920, 3)

# %%
plt.imshow(img)

# %% [markdown]
# #For Real Color

# %%
img = cv2.imread(image_path,cv2.IMREAD_COLOR)
img = cv2.cvtColor(img, cv2.COLOR_RGB2BGR)
plt.imshow(img)

# %%
img.shape
# Out:
# (1080, 1920, 3)

# %%
print('Top End',img[0,0])
print('Top right',img[0,1920-1])
print('Bottom left',img[1080-1,0])
print('Bottom right',img[1080-1,1920-1])
# Out:
# Top End [246 254 255]
# Top right [ 44 153 132]
# Bottom left [124 225 159]
# Bottom right [123 226 157]

# %%
rezied = cv2.resize(img,None,fx=2,fy=2,interpolation= cv2.INTER_BITS)

# %%
plt.imshow(rezied)

# %%
img  = cv2.resize(img, (128, 128))

# %%
plt.imshow(img)
